# %% [markdown]
# #*House Prices Preprocessing Notebook 🏠*

# %% [markdown]
# # **About Dataset** 📊

# %% [markdown]
# ### **Context:**
#
# The dataset is centered around the real estate market, focusing on residential property sales. It's a rich, multidimensional dataset that offers extensive details about property features, reflecting the nuances and complexities of the housing market. The analysis of such data is vital for stakeholders including home buyers, sellers, real estate agents, and market analysts, providing them with insights into market trends, property valuations, and investment opportunities.
#
# ### **Dataset Description:**
#
# The dataset encapsulates a broad spectrum of information about residential properties, spanning various aspects from basic configuration to detailed attributes that potentially influence the sale price. Key aspects covered in the dataset include:
#
# **`Property Basics:`**
# - Information about the type of dwelling, zoning classification, lot size, and street access.
#
# **`Physical Characteristics:`**
# - Descriptions of the lot shape, land contour, and utility features.
#
# **`Quality and Condition:`**
# - Evaluations encompassing the overall material and finish quality of the house, the state of various structural components, and the age of the property.
#
# **`Space and Layout:`**
# - Detailed information on living spaces, including size measurements, the number of rooms, bathrooms, and bedrooms, as well as kitchen quality.
#
# **`Additional Features:`**
# -  Insights into additional amenities and features such as fireplaces, garages, pools, and other miscellaneous elements.
#
#
# **`Sale Details:`**
# - Information regarding the sale transaction, including the date of sale, type, and condition of sale.

# %% [markdown]
# # **1. Data Acquisition & Exploration** 🧐

# %% [markdown]
# First, we need to import the libraries and load the dataset and familiarize ourselves with it's basic structure.
# We'll check the top rows, understand the types of data we're dealing with.

# %% [markdown]
# - **Importing the libraries we'll be using for this analysis.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - **Loading the dataset and checking the top 7 rows.**

# %%
df= pd.read_csv('train.csv')
df.head(7)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# - **Check the dimensions of the data**

# %%
 df.shape
# Out:
# (1460, 81)

# %% [markdown]
# - **Check the last rows**

# %%
df.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# - **check columns name**

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# -  **Sneap Peak of the dataset.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# - **Statistical Overview of the dataset.**

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# - **Check data unique in each column**

# %%
#number of unique values in each column
df.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %% [markdown]
# #  **2. Dealing with Missing Values** 🧽

# %%
df.isna()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
#number of missing values in each column
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# only show columns with missing values in ascending order
df.isnull().sum()[df.isnull().sum() > 0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# percentage of missing values
df.isnull().sum()[df.isnull().sum() > 0].sort_values(ascending=False) / len(df) * 100
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# MasVnrType      59.726027
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# BsmtQual         2.534247
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64

# %%
missing=df.isnull().sum()[df.isnull().sum() > 0].sort_values(ascending=False) / len(df) * 100
missing.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### **Checking the columns with most missing values**

# %% [markdown]
# #### **1. PoolQC: Pool quality**
#
# - Ex:	Excellent
# - Gd:	Good
# - TA:	Average/Typical
# - Fa:	Fair
# - NA:	No Pool

# %%
df["PoolQC"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: PoolQC, dtype: object

# %% [markdown]
# #### **2. MiscFeature: Miscellaneous feature not covered in other categories**
#
# - Elev:	Elevator
# - Gar2:	2nd Garage (if not described in garage section)
# - Othr:	Other
# - Shed:	Shed (over 100 SF)
# - TenC:	Tennis Court
# - NA:	None

# %%
df["MiscFeature"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: MiscFeature, dtype: object

# %% [markdown]
# #### **3. Alley: Type of alley access to property**
#
# - Grvl:	Gravel
# - Pave:	Paved
# - NA: 	No alley access

# %%
df["Alley"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Alley, dtype: object

# %% [markdown]
# #### **4. Fence**
#
# - GdPrv:	Good Privacy
# - MnPrv:	Minimum Privacy
# - GdWo:	Good Wood
# - MnWw:	Minimum Wood/Wire
# - NA: 	No Fence

# %%
df["Fence"].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Fence, dtype: object

# %% [markdown]
# ##**Drop columns**

# %% [markdown]
# - Dropped these columns because they have more than 70% missing values and they don't have impact on SalePrice.

# %%
df.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], axis=1 , inplace=True)

# %%
# percentage of missing values
df.isnull().sum()[df.isnull().sum() > 0].sort_values(ascending=False) / len(df) * 100
# Out:
# MasVnrType      59.726027
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtExposure     2.602740
# BsmtFinType2     2.602740
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtFinType1     2.534247
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64

# %%
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# ###**Drop Rows**

# %% [markdown]
# - We have one missing observation in 'Electrical'. Since it is just one observation, we'll delete this observation and keep the variable.

# %%
df = df.dropna(subset=['Electrical'])

# %%
colonnes_manquantes = df.columns[df.isnull().any()].tolist()

# %%
colonnes_manquantes
# Out:
# ['LotFrontage',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
df[colonnes_manquantes].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1459 entries, 0 to 1459
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotFrontage   1200 non-null   float64
#  1   MasVnrType    588 non-null    object
#  2   MasVnrArea    1451 non-null   float64
#  3   BsmtQual      1422 non-null   object
#  4   BsmtCond      1422 non-null   object
#  5   BsmtExposure  1421 non-null   object
#  6   BsmtFinType1  1422 non-null   object
#  7   BsmtFinType2  1421 non-null   object
#  8   FireplaceQu   770 non-null    object
#  9   GarageType    1378 non-null   object
#  10  GarageYrBlt   1378 non-null   float64
#  11  GarageFinish  1378 non-null   object
#  12  GarageQual    1378 non-null   object
#  13  GarageCond    1378 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 171.0+ KB

# %% [markdown]
# ###**Interpretation**: 📈 💡
# We notice that out of the 14 columns containing missing values , only 3 are **numerical** while the other 11 columns are **categorical**.
# => As a result, when dealing with missing values, we will address each type differently.
#
#
#
# 1.   **For the categorical columns:**
#
# We will replace the missing values with the most frequent value **"mode"** for each respective column. This approach is suitable for categorical data.
# 2.   **For the  numerical columns:**
#
#
#
# Our strategy will depend on "the presence of outliers" within each column. If **outliers are minimal or absent**, we can consider replacing missing values with either the mean or median of the column.
#
#  However, if **outliers are present**, we should exercise caution. In such cases, replacing missing values with the mean might skew the distribution, and it might be more appropriate to use the median or even the mode, depending on the specific characteristics of the data and the context of the analysis.

# %% [markdown]
# ### **Imputation of categorical columns**

# %% [markdown]
# *   **Using SimpleImputer :**

# %% [markdown]
# PS: SimpleImputer and fillna() are equivalent

# %%
# Create a SimpleImputer with the strategy 'most_frequent'
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')

# %%
df.loc[:,'MasVnrType'] = imputer.fit_transform(df[['MasVnrType']])

# %% [markdown]
# *   **Using Fillna() :**

# %%
# Impute missing values for categorical columns with the most frequent value
categorical_columns = ['BsmtExposure','BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond']
for column in categorical_columns:
    df[column].fillna(df[column].mode()[0], inplace=True)
# Out:
# <ipython-input-111-fe3b48e60fbb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column].fillna(df[column].mode()[0], inplace=True)

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %% [markdown]
# ### **Imputation of numerical columns**

# %% [markdown]
# ### **Boxplot to visualize outliers**

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['LotFrontage', 'MasVnrArea', 'GarageYrBlt']], orient='h')
plt.xlabel('Value')
plt.ylabel('Numerical Columns')
plt.title('Boxplots of Numerical Columns')
# Out:
# Text(0.5, 1.0, 'Boxplots of Numerical Columns')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df['LotFrontage'], orient='h')
plt.xlabel('Value')
plt.ylabel('LotFrontage')
plt.title('Boxplots of Numerical Columns')
# Out:
# Text(0.5, 1.0, 'Boxplots of Numerical Columns')

# %% [markdown]
# ###Interpretation: 📈 💡
#
# * We notice that one of the boxplots which belong to 'GarageYrBlt' column does **not contain any outliers**, So the data in that column is relatively well-behaved and normally distributed.
#
# => For the 'GarageYrBlt' column, using the **mean value** for imputation of missing values is a reasonable approach.
#
# * However, for the columns with outliers which are ['LotFrontage', 'MasVnrArea'], it's essential to handle them carefully to avoid biasing the imputation process. Here are a few strategies you could consider:
#
# 1. **Use Median or Mode:** Instead of the mean, you can use the median or the mode value for imputation. Theyn are less sensitive to outliers compared to the mean.
# 2. **Handle Outliers Separately**: You can identify and handle outliers separately from the imputation process. For example, you could cap or winsorize the outliers to a certain percentile (e.g., replace values above the 95th percentile with the value at the 95th percentile).
# 3. **Use a Robust Imputation Method:** There are imputation methods specifically designed to handle outliers, such as robust regression imputation or iterative imputation algorithms that are less affected by outliers.
#
# Ultimately, the choice of method depends on the specific characteristics of your data, the nature of the outliers, and the goals of your analysis. It's often a good idea to explore different strategies and assess their impact on your results.

# %% [markdown]
# ### **Replace the missing values of the 'GarageYrBlt' column**

# %%
# Calculate the mean of the column
mean_value = df['GarageYrBlt'].mean()

# Replace missing values with the mean
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(mean_value)

# %% [markdown]
# ### **Replace the missing values of the 'LotFrontage' and 'MasVnrArea' columns**

# %% [markdown]
# 1. **LotFrontage:**
#
# * Since 'LotFrontage' represents the linear feet of street connected to the property, it's likely correlated with other features such as lot size, neighborhood, or property type.
#
# * One approach could be to impute missing values using **the median** 'LotFrontage' value for properties within the same neighborhood. This can help capture local variations in lot sizes and street frontages.
#
# 2. **MasVnrArea:**
#
# * 'MasVnrArea' represents the masonry veneer area in square feet. Since this is a continuous variable, you can consider imputing missing values using **the median or mean** value of the column.
#
# => For outliers, you may consider a robust imputation method such as Winsorization, where extreme values are replaced with values at a specified percentile (e.g., 95th percentile).

# %%
from scipy.stats.mstats import winsorize

# %%
# Impute missing values for 'LotFrontage' by median within each neighborhood
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

# %%
# Winsorize outliers for 'MasVnrArea'
df['MasVnrArea'] = winsorize(df['MasVnrArea'], limits=[0.1, 0.1])

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[ 'MasVnrArea'], orient='h')
plt.xlabel('Value')
plt.ylabel('MasVnrArea')
plt.title('Boxplots of Numerical Columns')
# Out:
# Text(0.5, 1.0, 'Boxplots of Numerical Columns')

# %%
# Impute missing values for 'MasVnrArea' by median of the column
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ==> So know we have not any missing values finally 🥳

# %% [markdown]
# #  **3. Dealing with Duplicates**

# %%
# Check for duplicate rows
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 77 columns]

# %% [markdown]
# We have not any duplicates 🎉

# %%
df.shape
# Out:
# (1459, 77)

# %% [markdown]
# # **4. Dealing with Categorical data**

# %%
# One-hot encoding for categorical variable 'GarageType'
df = pd.get_dummies(df, columns=['GarageType'], drop_first=True)

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3           65     8450       1         3
# 1   2          20         3           80     9600       1         3
# 2   3          60         3           68    11250       1         0
# 3   4          70         3           60     9550       1         0
# 4   5          60         3           84    14260       1         0
#
#    LandContour  Utilities  LotConfig  ...  MoSold  YrSold  SaleType  \
# 0            3          0          4  ...       2    2008         8
# 1            3          0          2  ...       5    2007         8
# 2            3          0          4  ...       9    2008         8
# 3            3          0          0  ...       2    2006         8
# 4            3          0          2  ...      12    2008         8
#
#    SaleCondition  SalePrice  GarageType_Attchd  GarageType_Basment  \
# 0              4     208500                  1                   0
# ...

# %%
#Label encoding for the other categorical columns
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig  ...  MoSold  YrSold  SaleType  \
# 0            3          0          4  ...       2    2008         8
# 1            3          0          2  ...       5    2007         8
# 2            3          0          4  ...       9    2008         8
# 3            3          0          0  ...       2    2006         8
# 4            3          0          2  ...      12    2008         8
#
#    SaleCondition  SalePrice  GarageType_Attchd  GarageType_Basment  \
# 0              4     208500               True               False
# ...

# %%
df.describe().T
# Out:
#                      count          mean          std     min     25%     50%  \
# Id                  1459.0    730.054832   421.411181     1.0   365.5   730.0
# MSSubClass          1459.0     56.881426    42.310746    20.0    20.0    50.0
# MSZoning            1459.0      3.028787     0.632234     0.0     3.0     3.0
# LotFrontage         1459.0     70.187114    22.440654    21.0    60.0    70.0
# LotArea             1459.0  10517.363948  9984.666267  1300.0  7549.0  9477.0
# ...                    ...           ...          ...     ...     ...     ...
# GarageType_Attchd   1459.0      0.651816     0.476558     0.0     0.0     1.0
# GarageType_Basment  1459.0      0.013023     0.113410     0.0     0.0     0.0
# GarageType_BuiltIn  1459.0      0.059630     0.236881     0.0     0.0     0.0
# GarageType_CarPort  1459.0      0.006169     0.078325     0.0     0.0     0.0
# GarageType_Detchd   1459.0      0.265250     0.441618     0.0     0.0     0.0
#
# ...

# %% [markdown]
# #**My contact:**
# @Hajer Zitouni: hajer.zitouni105@gmail.com @[Linked in](https://www.linkedin.com/in/hajer-zitouni-564ba51b4/)
